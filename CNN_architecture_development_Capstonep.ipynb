# %% [markdown]
# <a href="https://colab.research.google.com/github/SudiWafula/DATA-ANALYTICS-CAPSTONE-PROJECT/blob/main/CNN_architecture_development_Capstonep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading the relevant libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import random
import cv2
from skimage.transform import resize
import pickle

# %%
file_path = '/content/drive/MyDrive/crop_resized_images.pkl'

with open(file_path, 'rb') as file:
    X_array = pickle.load(file)

# %%
plt.figure()
plt.imshow(X_array[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
import pickle

file_path = '/content/drive/My Drive/y_array.pkl'

with open(file_path, 'rb') as f:
    y_array = pickle.load(f)

# %%
train_images, test_images, train_labels, test_labels = train_test_split(X_array, y_array, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 37.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ***Stage 2: CONVOLUTIONAL NEURAL NETWORKS (CNN)***

# %%
# Basic CNN
image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 30
batch_size = 15

class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(image_height, image_width, num_channels)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print_accuracy_callback = PrintAccuracyCallback()

model.summary()

basic_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                           validation_data=(test_images, test_labels), callbacks=[print_accuracy_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  flatten (Flatten)           (None, 394272)            0
#
#  dense (Dense)               (None, 8)                 3154184
#
# =================================================================
# Total params: 3,155,080
# Trainable params: 3,155,080
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 213/214 [============================>.] - ETA: 0s - loss: 5.2053 - accuracy: 0.5383Accuracy: 53.91%
# 214/214 [==============================] - 25s 111ms/step - loss: 5.1976 - accuracy: 0.5391 - val_loss: 0.8533 - val_accuracy: 0.7075
# Epoch 2/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.8163Accuracy: 81.66%
# 214/214 [==============================] - 22s 103ms/step - loss: 0.5468 - accuracy: 0.8166 - val_loss: 0.5886 - val_accuracy: 0.7763
# Epoch 3/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.3200 - accuracy: 0.8989Accuracy: 89.91%
# 214/214 [==============================] - 22s 103ms/step - loss: 0.3198 - accuracy: 0.8991 - val_loss: 0.4665 - val_accuracy: 0.8125
# Epoch 4/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.1806 - accuracy: 0.9524Accuracy: 95.25%
# 214/214 [==============================] - 23s 105ms/step - loss: 0.1804 - accuracy: 0.9525 - val_loss: 0.3899 - val_accuracy: 0.8562
# Epoch 5/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0900 - accuracy: 0.9828Accuracy: 98.28%
# 214/214 [==============================] - 22s 104ms/step - loss: 0.0898 - accuracy: 0.9828 - val_loss: 0.4749 - val_accuracy: 0.8300
# Epoch 6/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9953Accuracy: 99.53%
# 214/214 [==============================] - 22s 104ms/step - loss: 0.0474 - accuracy: 0.9953 - val_loss: 0.3243 - val_accuracy: 0.8788
# Epoch 7/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9956Accuracy: 99.56%
# 214/214 [==============================] - 22s 105ms/step - loss: 0.0332 - accuracy: 0.9956 - val_loss: 0.3617 - val_accuracy: 0.8737
# Epoch 8/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9991Accuracy: 99.91%
# 214/214 [==============================] - 22s 105ms/step - loss: 0.0167 - accuracy: 0.9991 - val_loss: 0.3406 - val_accuracy: 0.8788
# Epoch 9/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 22s 103ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.3119 - val_accuracy: 0.8888
# Epoch 10/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9997Accuracy: 99.97%
# 214/214 [==============================] - 22s 103ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.3625 - val_accuracy: 0.8800
# Epoch 11/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 106ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3088 - val_accuracy: 0.9000
# Epoch 12/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 24s 110ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3030 - val_accuracy: 0.9013
# Epoch 13/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 22s 104ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2944 - val_accuracy: 0.9013
# Epoch 14/30
# 213/214 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 24s 112ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9062
# Epoch 15/30
# 213/214 [============================>.] - ETA: 0s - loss: 9.5587e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 105ms/step - loss: 9.5445e-04 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9100
# Epoch 16/30
# 213/214 [============================>.] - ETA: 0s - loss: 8.3717e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 22s 104ms/step - loss: 8.3739e-04 - accuracy: 1.0000 - val_loss: 0.2959 - val_accuracy: 0.9050
# Epoch 17/30
# 213/214 [============================>.] - ETA: 0s - loss: 6.9340e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 107ms/step - loss: 6.9325e-04 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.9075
# Epoch 18/30
# 213/214 [============================>.] - ETA: 0s - loss: 6.3810e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 22s 105ms/step - loss: 6.3888e-04 - accuracy: 1.0000 - val_loss: 0.2960 - val_accuracy: 0.9087
# Epoch 19/30
# 214/214 [==============================] - ETA: 0s - loss: 5.1138e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 107ms/step - loss: 5.1138e-04 - accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.9112
# Epoch 20/30
# 213/214 [============================>.] - ETA: 0s - loss: 4.6426e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 106ms/step - loss: 4.6424e-04 - accuracy: 1.0000 - val_loss: 0.2963 - val_accuracy: 0.9125
# Epoch 21/30
# 213/214 [============================>.] - ETA: 0s - loss: 4.2307e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 110ms/step - loss: 4.2342e-04 - accuracy: 1.0000 - val_loss: 0.3029 - val_accuracy: 0.9100
# Epoch 22/30
# 213/214 [============================>.] - ETA: 0s - loss: 3.5892e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 106ms/step - loss: 3.5892e-04 - accuracy: 1.0000 - val_loss: 0.2952 - val_accuracy: 0.9125
# Epoch 23/30
# 213/214 [============================>.] - ETA: 0s - loss: 3.2798e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 22s 105ms/step - loss: 3.2889e-04 - accuracy: 1.0000 - val_loss: 0.2921 - val_accuracy: 0.9162
# Epoch 24/30
# 213/214 [============================>.] - ETA: 0s - loss: 2.8365e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 108ms/step - loss: 2.8327e-04 - accuracy: 1.0000 - val_loss: 0.3017 - val_accuracy: 0.9125
# Epoch 25/30
# 213/214 [============================>.] - ETA: 0s - loss: 2.4358e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 106ms/step - loss: 2.4403e-04 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9162
# Epoch 26/30
# 213/214 [============================>.] - ETA: 0s - loss: 2.1444e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 106ms/step - loss: 2.1495e-04 - accuracy: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.9050
# Epoch 27/30
# 213/214 [============================>.] - ETA: 0s - loss: 1.9301e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 107ms/step - loss: 1.9309e-04 - accuracy: 1.0000 - val_loss: 0.3038 - val_accuracy: 0.9137
# Epoch 28/30
# 213/214 [============================>.] - ETA: 0s - loss: 1.6802e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 108ms/step - loss: 1.6784e-04 - accuracy: 1.0000 - val_loss: 0.2964 - val_accuracy: 0.9125
# Epoch 29/30
# 213/214 [============================>.] - ETA: 0s - loss: 1.5523e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 109ms/step - loss: 1.5499e-04 - accuracy: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9200
# Epoch 30/30
# 213/214 [============================>.] - ETA: 0s - loss: 1.3586e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 23s 108ms/step - loss: 1.3590e-04 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9137

# %%
# training and validation loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(basic_cnn_hist.history['loss'], label='Training Loss')
plt.plot(basic_cnn_hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(basic_cnn_hist.history['accuracy'], label='Training Accuracy')
plt.plot(basic_cnn_hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 1s 51ms/step

# %%
class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

def create_basic_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu')) #added layer
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print_accuracy_callback = PrintAccuracyCallback()
    model.summary()
    basic_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                               validation_data=(test_images, test_labels), callbacks=[print_accuracy_callback])
    return basic_cnn_hist

image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 30
batch_size = 15

model = create_basic_cnn_model(input_shape=(image_height, image_width, num_channels), num_classes=num_classes)

basic_cnn_hist2 = train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_1 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_2 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 186624)            0
#
#  dense_1 (Dense)             (None, 8)                 1493000
#
# =================================================================
# Total params: 1,512,392
# Trainable params: 1,512,392
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 214/214 [==============================] - ETA: 0s - loss: 1.2123 - accuracy: 0.6087Accuracy: 60.87%
# 214/214 [==============================] - 46s 209ms/step - loss: 1.2123 - accuracy: 0.6087 - val_loss: 0.6089 - val_accuracy: 0.7900
# Epoch 2/30
# 214/214 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8666Accuracy: 86.66%
# 214/214 [==============================] - 45s 208ms/step - loss: 0.3940 - accuracy: 0.8666 - val_loss: 0.4793 - val_accuracy: 0.8050
# Epoch 3/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.8931Accuracy: 89.31%
# 214/214 [==============================] - 44s 206ms/step - loss: 0.2876 - accuracy: 0.8931 - val_loss: 0.5560 - val_accuracy: 0.7825
# Epoch 4/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9447Accuracy: 94.47%
# 214/214 [==============================] - 45s 209ms/step - loss: 0.1805 - accuracy: 0.9447 - val_loss: 0.3102 - val_accuracy: 0.8925
# Epoch 5/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9750Accuracy: 97.50%
# 214/214 [==============================] - 44s 207ms/step - loss: 0.0856 - accuracy: 0.9750 - val_loss: 0.3575 - val_accuracy: 0.8863
# Epoch 6/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9841Accuracy: 98.41%
# 214/214 [==============================] - 45s 212ms/step - loss: 0.0564 - accuracy: 0.9841 - val_loss: 0.3579 - val_accuracy: 0.8863
# Epoch 7/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9919Accuracy: 99.19%
# 214/214 [==============================] - 45s 212ms/step - loss: 0.0265 - accuracy: 0.9919 - val_loss: 0.4165 - val_accuracy: 0.8725
# Epoch 8/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9953Accuracy: 99.53%
# 214/214 [==============================] - 46s 213ms/step - loss: 0.0193 - accuracy: 0.9953 - val_loss: 0.3156 - val_accuracy: 0.9075
# Epoch 9/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9934Accuracy: 99.34%
# 214/214 [==============================] - 45s 211ms/step - loss: 0.0245 - accuracy: 0.9934 - val_loss: 0.4266 - val_accuracy: 0.8850
# Epoch 10/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9941Accuracy: 99.41%
# 214/214 [==============================] - 45s 209ms/step - loss: 0.0176 - accuracy: 0.9941 - val_loss: 0.4668 - val_accuracy: 0.8637
# Epoch 11/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9891Accuracy: 98.91%
# 214/214 [==============================] - 45s 210ms/step - loss: 0.0323 - accuracy: 0.9891 - val_loss: 0.5973 - val_accuracy: 0.8413
# Epoch 12/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9931Accuracy: 99.31%
# 214/214 [==============================] - 45s 211ms/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 0.4490 - val_accuracy: 0.8800
# Epoch 13/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9987Accuracy: 99.87%
# 214/214 [==============================] - 45s 209ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.4875 - val_accuracy: 0.8875
# Epoch 14/30
# 214/214 [==============================] - ETA: 0s - loss: 4.3482e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 44s 206ms/step - loss: 4.3482e-04 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.8988
# Epoch 15/30
# 214/214 [==============================] - ETA: 0s - loss: 2.3579e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 210ms/step - loss: 2.3579e-04 - accuracy: 1.0000 - val_loss: 0.4425 - val_accuracy: 0.8988
# Epoch 16/30
# 214/214 [==============================] - ETA: 0s - loss: 1.6804e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 208ms/step - loss: 1.6804e-04 - accuracy: 1.0000 - val_loss: 0.4510 - val_accuracy: 0.8975
# Epoch 17/30
# 214/214 [==============================] - ETA: 0s - loss: 1.3107e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 211ms/step - loss: 1.3107e-04 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.8963
# Epoch 18/30
# 214/214 [==============================] - ETA: 0s - loss: 1.0735e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 210ms/step - loss: 1.0735e-04 - accuracy: 1.0000 - val_loss: 0.4593 - val_accuracy: 0.8963
# Epoch 19/30
# 214/214 [==============================] - ETA: 0s - loss: 9.0548e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 44s 205ms/step - loss: 9.0548e-05 - accuracy: 1.0000 - val_loss: 0.4631 - val_accuracy: 0.8963
# Epoch 20/30
# 214/214 [==============================] - ETA: 0s - loss: 7.7023e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 44s 207ms/step - loss: 7.7023e-05 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.8950
# Epoch 21/30
# 214/214 [==============================] - ETA: 0s - loss: 6.6571e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 44s 208ms/step - loss: 6.6571e-05 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.8963
# Epoch 22/30
# 214/214 [==============================] - ETA: 0s - loss: 5.7931e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 44s 207ms/step - loss: 5.7931e-05 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.8975
# Epoch 23/30
# 214/214 [==============================] - ETA: 0s - loss: 5.0613e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 209ms/step - loss: 5.0613e-05 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.8975
# Epoch 24/30
# 214/214 [==============================] - ETA: 0s - loss: 4.4478e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 209ms/step - loss: 4.4478e-05 - accuracy: 1.0000 - val_loss: 0.4795 - val_accuracy: 0.8963
# Epoch 25/30
# 214/214 [==============================] - ETA: 0s - loss: 3.9114e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 210ms/step - loss: 3.9114e-05 - accuracy: 1.0000 - val_loss: 0.4878 - val_accuracy: 0.8988
# Epoch 26/30
# 214/214 [==============================] - ETA: 0s - loss: 3.4792e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 210ms/step - loss: 3.4792e-05 - accuracy: 1.0000 - val_loss: 0.4879 - val_accuracy: 0.9000
# Epoch 27/30
# 214/214 [==============================] - ETA: 0s - loss: 3.0932e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 211ms/step - loss: 3.0932e-05 - accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.8975
# Epoch 28/30
# 214/214 [==============================] - ETA: 0s - loss: 2.7594e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 212ms/step - loss: 2.7594e-05 - accuracy: 1.0000 - val_loss: 0.4957 - val_accuracy: 0.9013
# Epoch 29/30
# 214/214 [==============================] - ETA: 0s - loss: 2.4765e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 45s 209ms/step - loss: 2.4765e-05 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.9000
# Epoch 30/30
# 214/214 [==============================] - ETA: 0s - loss: 2.1780e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 44s 208ms/step - loss: 2.1780e-05 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.8963

# %%
# training and validation loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(basic_cnn_hist2.history['loss'], label='Training Loss')
plt.plot(basic_cnn_hist2.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(basic_cnn_hist2.history['accuracy'], label='Training Accuracy')
plt.plot(basic_cnn_hist2.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

confus_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confus_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 2s 73ms/step

# %%
class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

def create_basic_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print_accuracy_callback = PrintAccuracyCallback()
    model.summary()
    basic_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                               validation_data=(test_images, test_labels), callbacks=[print_accuracy_callback])
    return basic_cnn_hist

# constants
image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 30
batch_size = 15

model = create_basic_cnn_model(input_shape=(image_height, image_width, num_channels), num_classes=num_classes)

basic_cnn_hist3 = train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_4 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 186624)            0
#
#  dense_2 (Dense)             (None, 128)               23888000
#
#  dense_3 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 23,908,424
# Trainable params: 23,908,424
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 214/214 [==============================] - ETA: 0s - loss: 1.4870 - accuracy: 0.5372Accuracy: 53.72%
# 214/214 [==============================] - 68s 315ms/step - loss: 1.4870 - accuracy: 0.5372 - val_loss: 0.5373 - val_accuracy: 0.8125
# Epoch 2/30
# 214/214 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.8637Accuracy: 86.37%
# 214/214 [==============================] - 70s 325ms/step - loss: 0.3885 - accuracy: 0.8637 - val_loss: 0.3647 - val_accuracy: 0.8612
# Epoch 3/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9253Accuracy: 92.53%
# 214/214 [==============================] - 69s 322ms/step - loss: 0.2209 - accuracy: 0.9253 - val_loss: 0.3175 - val_accuracy: 0.8875
# Epoch 4/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9731Accuracy: 97.31%
# 214/214 [==============================] - 71s 332ms/step - loss: 0.0939 - accuracy: 0.9731 - val_loss: 0.4915 - val_accuracy: 0.8487
# Epoch 5/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9794Accuracy: 97.94%
# 214/214 [==============================] - 80s 374ms/step - loss: 0.0675 - accuracy: 0.9794 - val_loss: 0.2267 - val_accuracy: 0.9200
# Epoch 6/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9959Accuracy: 99.59%
# 214/214 [==============================] - 76s 354ms/step - loss: 0.0185 - accuracy: 0.9959 - val_loss: 0.2640 - val_accuracy: 0.9175
# Epoch 7/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9856Accuracy: 98.56%
# 214/214 [==============================] - 69s 324ms/step - loss: 0.0441 - accuracy: 0.9856 - val_loss: 0.2311 - val_accuracy: 0.9275
# Epoch 8/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9994Accuracy: 99.94%
# 214/214 [==============================] - 70s 327ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.2334 - val_accuracy: 0.9137
# Epoch 9/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9956Accuracy: 99.56%
# 214/214 [==============================] - 66s 310ms/step - loss: 0.0116 - accuracy: 0.9956 - val_loss: 0.2307 - val_accuracy: 0.9300
# Epoch 10/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9997Accuracy: 99.97%
# 214/214 [==============================] - 66s 308ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.2829 - val_accuracy: 0.9062
# Epoch 11/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997Accuracy: 99.97%
# 214/214 [==============================] - 66s 311ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.2044 - val_accuracy: 0.9250
# Epoch 12/30
# 214/214 [==============================] - ETA: 0s - loss: 3.5132e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 65s 305ms/step - loss: 3.5132e-04 - accuracy: 1.0000 - val_loss: 0.2155 - val_accuracy: 0.9237
# Epoch 13/30
# 214/214 [==============================] - ETA: 0s - loss: 2.1754e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 67s 311ms/step - loss: 2.1754e-04 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9262
# Epoch 14/30
# 214/214 [==============================] - ETA: 0s - loss: 1.6806e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 67s 312ms/step - loss: 1.6806e-04 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9262
# Epoch 15/30
# 214/214 [==============================] - ETA: 0s - loss: 1.3588e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 308ms/step - loss: 1.3588e-04 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9237
# Epoch 16/30
# 214/214 [==============================] - ETA: 0s - loss: 1.1370e-04 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 67s 312ms/step - loss: 1.1370e-04 - accuracy: 1.0000 - val_loss: 0.2301 - val_accuracy: 0.9250
# Epoch 17/30
# 214/214 [==============================] - ETA: 0s - loss: 9.4185e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 67s 312ms/step - loss: 9.4185e-05 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9275
# Epoch 18/30
# 214/214 [==============================] - ETA: 0s - loss: 8.0318e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 306ms/step - loss: 8.0318e-05 - accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.9262
# Epoch 19/30
# 214/214 [==============================] - ETA: 0s - loss: 6.8331e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 65s 303ms/step - loss: 6.8331e-05 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9262
# Epoch 20/30
# 214/214 [==============================] - ETA: 0s - loss: 5.8991e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 65s 305ms/step - loss: 5.8991e-05 - accuracy: 1.0000 - val_loss: 0.2346 - val_accuracy: 0.9300
# Epoch 21/30
# 214/214 [==============================] - ETA: 0s - loss: 5.1449e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 67s 312ms/step - loss: 5.1449e-05 - accuracy: 1.0000 - val_loss: 0.2386 - val_accuracy: 0.9275
# Epoch 22/30
# 214/214 [==============================] - ETA: 0s - loss: 4.4189e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 307ms/step - loss: 4.4189e-05 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9275
# Epoch 23/30
# 214/214 [==============================] - ETA: 0s - loss: 3.8198e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 65s 303ms/step - loss: 3.8198e-05 - accuracy: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9287
# Epoch 24/30
# 214/214 [==============================] - ETA: 0s - loss: 3.3272e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 65s 303ms/step - loss: 3.3272e-05 - accuracy: 1.0000 - val_loss: 0.2408 - val_accuracy: 0.9312
# Epoch 25/30
# 214/214 [==============================] - ETA: 0s - loss: 2.8373e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 64s 301ms/step - loss: 2.8373e-05 - accuracy: 1.0000 - val_loss: 0.2401 - val_accuracy: 0.9337
# Epoch 26/30
# 214/214 [==============================] - ETA: 0s - loss: 2.4478e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 65s 303ms/step - loss: 2.4478e-05 - accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.9350
# Epoch 27/30
# 214/214 [==============================] - ETA: 0s - loss: 2.0926e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 309ms/step - loss: 2.0926e-05 - accuracy: 1.0000 - val_loss: 0.2500 - val_accuracy: 0.9325
# Epoch 28/30
# 214/214 [==============================] - ETA: 0s - loss: 1.7729e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 310ms/step - loss: 1.7729e-05 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9312
# Epoch 29/30
# 214/214 [==============================] - ETA: 0s - loss: 1.5006e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 311ms/step - loss: 1.5006e-05 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9312
# Epoch 30/30
# 214/214 [==============================] - ETA: 0s - loss: 1.2720e-05 - accuracy: 1.0000Accuracy: 100.00%
# 214/214 [==============================] - 66s 308ms/step - loss: 1.2720e-05 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9337

# %%
plt.plot(basic_cnn_hist3.history['accuracy'], label='Training Accuracy')
plt.plot(basic_cnn_hist3.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# training and validation loss
plt.plot(basic_cnn_hist3.history['loss'], label='Training Loss')
plt.plot(basic_cnn_hist3.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
preds = model.predict(test_images)
predicted_labels = np.argmax(preds, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

confx_mat = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confx_mat, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 2s 80ms/step

# %%
class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

def create_basic_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print_accuracy_callback = PrintAccuracyCallback()
    model.summary()
    basic_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                               validation_data=(test_images, test_labels), callbacks=[print_accuracy_callback])
    return basic_cnn_hist

# constants
image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 30
batch_size = 15

model = create_basic_cnn_model(input_shape=(image_height, image_width, num_channels), num_classes=num_classes)

basic_cnn_hist4 = train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_6 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 52, 52, 128)       73856
#
#  flatten_3 (Flatten)         (None, 346112)            0
#
#  dense_4 (Dense)             (None, 128)               44302464
#
#  dense_5 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 44,396,744
# Trainable params: 44,396,744
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 214/214 [==============================] - ETA: 0s - loss: 1.3657 - accuracy: 0.5238Accuracy: 52.38%
# 214/214 [==============================] - 78s 361ms/step - loss: 1.3657 - accuracy: 0.5238 - val_loss: 0.7798 - val_accuracy: 0.7013
# Epoch 2/10
# 214/214 [==============================] - ETA: 0s - loss: 0.4868 - accuracy: 0.8263Accuracy: 82.63%
# 214/214 [==============================] - 75s 349ms/step - loss: 0.4868 - accuracy: 0.8263 - val_loss: 0.5965 - val_accuracy: 0.7950
# Epoch 3/10
# 214/214 [==============================] - ETA: 0s - loss: 0.3216 - accuracy: 0.8850Accuracy: 88.50%
# 214/214 [==============================] - 75s 351ms/step - loss: 0.3216 - accuracy: 0.8850 - val_loss: 0.5222 - val_accuracy: 0.8037
# Epoch 4/10
# 214/214 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9375Accuracy: 93.75%
# 214/214 [==============================] - 74s 347ms/step - loss: 0.1895 - accuracy: 0.9375 - val_loss: 0.3407 - val_accuracy: 0.8838
# Epoch 5/10
# 214/214 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9650Accuracy: 96.50%
# 214/214 [==============================] - 75s 349ms/step - loss: 0.1086 - accuracy: 0.9650 - val_loss: 0.3350 - val_accuracy: 0.8863
# Epoch 6/10
# 214/214 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9666Accuracy: 96.66%
# 214/214 [==============================] - 75s 351ms/step - loss: 0.1130 - accuracy: 0.9666 - val_loss: 0.6452 - val_accuracy: 0.7775
# Epoch 7/10
# 214/214 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9566Accuracy: 95.66%
# 214/214 [==============================] - 75s 351ms/step - loss: 0.1272 - accuracy: 0.9566 - val_loss: 0.3906 - val_accuracy: 0.8875
# Epoch 8/10
# 214/214 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9872Accuracy: 98.72%
# 214/214 [==============================] - 74s 347ms/step - loss: 0.0479 - accuracy: 0.9872 - val_loss: 0.3366 - val_accuracy: 0.9025
# Epoch 9/10
# 214/214 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9453Accuracy: 94.53%
# 214/214 [==============================] - 75s 350ms/step - loss: 0.1637 - accuracy: 0.9453 - val_loss: 0.4522 - val_accuracy: 0.8888
# Epoch 10/10
# 214/214 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9947Accuracy: 99.47%
# 214/214 [==============================] - 75s 352ms/step - loss: 0.0166 - accuracy: 0.9947 - val_loss: 0.3827 - val_accuracy: 0.9112

# %%
# training and validation loss
plt.plot(basic_cnn_hist4.history['loss'], label='Training Loss')
plt.plot(basic_cnn_hist4.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# training and validation accuracy
plt.plot(basic_cnn_hist4.history['accuracy'], label='Training Accuracy')
plt.plot(basic_cnn_hist4.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
preds = model.predict(test_images)
predicted_labels = np.argmax(preds, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

confusion_matxx = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matxx, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 2s 94ms/step

# %%
class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

def create_basic_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print_accuracy_callback = PrintAccuracyCallback()
    model.summary()
    basic_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                               validation_data=(test_images, test_labels), callbacks=[print_accuracy_callback])
    return basic_cnn_hist

# constants
image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 30
batch_size = 15

model = create_basic_cnn_model(input_shape=(image_height, image_width, num_channels), num_classes=num_classes)

basic_cnn_hist5 = train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_6 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 52, 52, 128)       73856
#
#  flatten_3 (Flatten)         (None, 346112)            0
#
#  dense_4 (Dense)             (None, 128)               44302464
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_5 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 44,396,744
# Trainable params: 44,396,744
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 214/214 [==============================] - ETA: 0s - loss: 2.0196 - accuracy: 0.3034Accuracy: 30.34%
# 214/214 [==============================] - 95s 441ms/step - loss: 2.0196 - accuracy: 0.3034 - val_loss: 1.6756 - val_accuracy: 0.4500
# Epoch 2/30
# 214/214 [==============================] - ETA: 0s - loss: 1.3426 - accuracy: 0.5222Accuracy: 52.22%
# 214/214 [==============================] - 91s 428ms/step - loss: 1.3426 - accuracy: 0.5222 - val_loss: 1.1536 - val_accuracy: 0.6125
# Epoch 3/30
# 214/214 [==============================] - ETA: 0s - loss: 0.9978 - accuracy: 0.6513Accuracy: 65.13%
# 214/214 [==============================] - 92s 431ms/step - loss: 0.9978 - accuracy: 0.6513 - val_loss: 0.8646 - val_accuracy: 0.6825
# Epoch 4/30
# 214/214 [==============================] - ETA: 0s - loss: 0.7033 - accuracy: 0.7431Accuracy: 74.31%
# 214/214 [==============================] - 93s 435ms/step - loss: 0.7033 - accuracy: 0.7431 - val_loss: 0.7635 - val_accuracy: 0.7525
# Epoch 5/30
# 214/214 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.8194Accuracy: 81.94%
# 214/214 [==============================] - 96s 449ms/step - loss: 0.5043 - accuracy: 0.8194 - val_loss: 0.5851 - val_accuracy: 0.8150
# Epoch 6/30
# 214/214 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.8859Accuracy: 88.59%
# 214/214 [==============================] - 94s 440ms/step - loss: 0.3196 - accuracy: 0.8859 - val_loss: 0.6383 - val_accuracy: 0.7975
# Epoch 7/30
# 214/214 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8881Accuracy: 88.81%
# 214/214 [==============================] - 94s 441ms/step - loss: 0.3092 - accuracy: 0.8881 - val_loss: 0.7480 - val_accuracy: 0.7925
# Epoch 8/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.9038Accuracy: 90.38%
# 214/214 [==============================] - 96s 448ms/step - loss: 0.2711 - accuracy: 0.9038 - val_loss: 0.5946 - val_accuracy: 0.8175
# Epoch 9/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9375Accuracy: 93.75%
# 214/214 [==============================] - 94s 440ms/step - loss: 0.1778 - accuracy: 0.9375 - val_loss: 0.6473 - val_accuracy: 0.8350
# Epoch 10/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9606Accuracy: 96.06%
# 214/214 [==============================] - 94s 438ms/step - loss: 0.1270 - accuracy: 0.9606 - val_loss: 0.6439 - val_accuracy: 0.8587
# Epoch 11/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9463Accuracy: 94.63%
# 214/214 [==============================] - 94s 442ms/step - loss: 0.1564 - accuracy: 0.9463 - val_loss: 0.7155 - val_accuracy: 0.8263
# Epoch 12/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9588Accuracy: 95.88%
# 214/214 [==============================] - 96s 448ms/step - loss: 0.1253 - accuracy: 0.9588 - val_loss: 0.7872 - val_accuracy: 0.8100
# Epoch 13/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9541Accuracy: 95.41%
# 214/214 [==============================] - 94s 438ms/step - loss: 0.1357 - accuracy: 0.9541 - val_loss: 0.6846 - val_accuracy: 0.8400
# Epoch 14/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9488Accuracy: 94.88%
# 214/214 [==============================] - 94s 441ms/step - loss: 0.1731 - accuracy: 0.9488 - val_loss: 0.7315 - val_accuracy: 0.8225
# Epoch 15/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9753Accuracy: 97.53%
# 214/214 [==============================] - 94s 441ms/step - loss: 0.0772 - accuracy: 0.9753 - val_loss: 0.8200 - val_accuracy: 0.8288
# Epoch 16/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9716Accuracy: 97.16%
# 214/214 [==============================] - 97s 453ms/step - loss: 0.0785 - accuracy: 0.9716 - val_loss: 0.7290 - val_accuracy: 0.8450
# Epoch 17/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9725Accuracy: 97.25%
# 214/214 [==============================] - 97s 455ms/step - loss: 0.0893 - accuracy: 0.9725 - val_loss: 1.1566 - val_accuracy: 0.7738
# Epoch 18/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9744Accuracy: 97.44%
# 214/214 [==============================] - 96s 449ms/step - loss: 0.0786 - accuracy: 0.9744 - val_loss: 0.9611 - val_accuracy: 0.8062
# Epoch 19/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9675Accuracy: 96.75%
# 214/214 [==============================] - 94s 438ms/step - loss: 0.1065 - accuracy: 0.9675 - val_loss: 0.9296 - val_accuracy: 0.8150
# Epoch 20/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9741Accuracy: 97.41%
# 214/214 [==============================] - 94s 438ms/step - loss: 0.0788 - accuracy: 0.9741 - val_loss: 0.8399 - val_accuracy: 0.8487
# Epoch 21/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9744Accuracy: 97.44%
# 214/214 [==============================] - 94s 441ms/step - loss: 0.0701 - accuracy: 0.9744 - val_loss: 0.7393 - val_accuracy: 0.8413
# Epoch 22/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9809Accuracy: 98.09%
# 214/214 [==============================] - 96s 450ms/step - loss: 0.0653 - accuracy: 0.9809 - val_loss: 0.7587 - val_accuracy: 0.8487
# Epoch 23/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9697Accuracy: 96.97%
# 214/214 [==============================] - 97s 452ms/step - loss: 0.1096 - accuracy: 0.9697 - val_loss: 1.0585 - val_accuracy: 0.7862
# Epoch 24/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9737Accuracy: 97.37%
# 214/214 [==============================] - 99s 465ms/step - loss: 0.0807 - accuracy: 0.9737 - val_loss: 0.8452 - val_accuracy: 0.8163
# Epoch 25/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9812Accuracy: 98.12%
# 214/214 [==============================] - 99s 463ms/step - loss: 0.0537 - accuracy: 0.9812 - val_loss: 1.0080 - val_accuracy: 0.8100
# Epoch 26/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9859Accuracy: 98.59%
# 214/214 [==============================] - 98s 456ms/step - loss: 0.0396 - accuracy: 0.9859 - val_loss: 0.8908 - val_accuracy: 0.8462
# Epoch 27/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9878Accuracy: 98.78%
# 214/214 [==============================] - 99s 462ms/step - loss: 0.0409 - accuracy: 0.9878 - val_loss: 0.7071 - val_accuracy: 0.8712
# Epoch 28/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9847Accuracy: 98.47%
# 214/214 [==============================] - 96s 449ms/step - loss: 0.0512 - accuracy: 0.9847 - val_loss: 0.7693 - val_accuracy: 0.8487
# Epoch 29/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9841Accuracy: 98.41%
# 214/214 [==============================] - 97s 453ms/step - loss: 0.0449 - accuracy: 0.9841 - val_loss: 0.8204 - val_accuracy: 0.8712
# Epoch 30/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9622Accuracy: 96.22%
# 214/214 [==============================] - 96s 449ms/step - loss: 0.1237 - accuracy: 0.9622 - val_loss: 0.9464 - val_accuracy: 0.7825

# %%
# training and validation loss
plt.plot(basic_cnn_hist5.history['loss'], label='Training Loss')
plt.plot(basic_cnn_hist5.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# training and validation accuracy
plt.plot(basic_cnn_hist5.history['accuracy'], label='Training Accuracy')
plt.plot(basic_cnn_hist5.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
preds = model.predict(test_images)
predicted_labels = np.argmax(preds, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

confusion_matrxx = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrxx, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 3s 107ms/step

# %%
class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

def create_basic_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size):
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print_accuracy_callback = PrintAccuracyCallback()
    model.summary()
    basic_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                               validation_data=(test_images, test_labels), callbacks=[print_accuracy_callback])
    return basic_cnn_hist

# constants
image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 30
batch_size = 15

model = create_basic_cnn_model(input_shape=(image_height, image_width, num_channels), num_classes=num_classes)

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

basic_cnn_hist6 = train_basic_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_7 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_8 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 128)       73856
#
#  flatten_4 (Flatten)         (None, 346112)            0
#
#  dense_6 (Dense)             (None, 128)               44302464
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 44,396,744
# Trainable params: 44,396,744
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 214/214 [==============================] - ETA: 0s - loss: 2.1788 - accuracy: 0.2422Accuracy: 24.22%
# 214/214 [==============================] - 101s 468ms/step - loss: 2.1788 - accuracy: 0.2422 - val_loss: 2.0118 - val_accuracy: 0.2325
# Epoch 2/30
# 214/214 [==============================] - ETA: 0s - loss: 1.6954 - accuracy: 0.3853Accuracy: 38.53%
# 214/214 [==============================] - 100s 468ms/step - loss: 1.6954 - accuracy: 0.3853 - val_loss: 1.5130 - val_accuracy: 0.4288
# Epoch 3/30
# 214/214 [==============================] - ETA: 0s - loss: 1.3870 - accuracy: 0.4922Accuracy: 49.22%
# 214/214 [==============================] - 101s 474ms/step - loss: 1.3870 - accuracy: 0.4922 - val_loss: 1.5515 - val_accuracy: 0.4013
# Epoch 4/30
# 214/214 [==============================] - ETA: 0s - loss: 1.1572 - accuracy: 0.5950Accuracy: 59.50%
# 214/214 [==============================] - 103s 480ms/step - loss: 1.1572 - accuracy: 0.5950 - val_loss: 1.2509 - val_accuracy: 0.5150
# Epoch 5/30
# 214/214 [==============================] - ETA: 0s - loss: 0.8954 - accuracy: 0.6850Accuracy: 68.50%
# 214/214 [==============================] - 101s 474ms/step - loss: 0.8954 - accuracy: 0.6850 - val_loss: 1.5850 - val_accuracy: 0.5275
# Epoch 6/30
# 214/214 [==============================] - ETA: 0s - loss: 0.6861 - accuracy: 0.7694Accuracy: 76.94%
# 214/214 [==============================] - 100s 468ms/step - loss: 0.6861 - accuracy: 0.7694 - val_loss: 1.2955 - val_accuracy: 0.5800
# Epoch 7/30
# 214/214 [==============================] - ETA: 0s - loss: 0.5308 - accuracy: 0.8288Accuracy: 82.88%
# 214/214 [==============================] - 99s 463ms/step - loss: 0.5308 - accuracy: 0.8288 - val_loss: 1.3047 - val_accuracy: 0.5938
# Epoch 8/30
# 214/214 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8719Accuracy: 87.19%
# 214/214 [==============================] - 104s 484ms/step - loss: 0.3744 - accuracy: 0.8719 - val_loss: 1.6940 - val_accuracy: 0.5675
# Epoch 9/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2612 - accuracy: 0.9209Accuracy: 92.09%
# 214/214 [==============================] - 104s 484ms/step - loss: 0.2612 - accuracy: 0.9209 - val_loss: 1.6556 - val_accuracy: 0.6200
# Epoch 10/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.9237Accuracy: 92.37%
# 214/214 [==============================] - 104s 485ms/step - loss: 0.2465 - accuracy: 0.9237 - val_loss: 1.9137 - val_accuracy: 0.5813
# Epoch 11/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9438Accuracy: 94.38%
# 214/214 [==============================] - 103s 482ms/step - loss: 0.1662 - accuracy: 0.9438 - val_loss: 1.8938 - val_accuracy: 0.6000
# Epoch 12/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9647Accuracy: 96.47%
# 214/214 [==============================] - 107s 499ms/step - loss: 0.1288 - accuracy: 0.9647 - val_loss: 1.8372 - val_accuracy: 0.6137
# Epoch 13/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9591Accuracy: 95.91%
# 214/214 [==============================] - 108s 507ms/step - loss: 0.1300 - accuracy: 0.9591 - val_loss: 2.1106 - val_accuracy: 0.5888
# Epoch 14/30
# 214/214 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9728Accuracy: 97.28%
# 214/214 [==============================] - 105s 490ms/step - loss: 0.1070 - accuracy: 0.9728 - val_loss: 2.3510 - val_accuracy: 0.5775
# Epoch 15/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9753Accuracy: 97.53%
# 214/214 [==============================] - 109s 510ms/step - loss: 0.0767 - accuracy: 0.9753 - val_loss: 2.0527 - val_accuracy: 0.6037
# Epoch 16/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9741Accuracy: 97.41%
# 214/214 [==============================] - 107s 500ms/step - loss: 0.0900 - accuracy: 0.9741 - val_loss: 2.1355 - val_accuracy: 0.5713
# Epoch 17/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9828Accuracy: 98.28%
# 214/214 [==============================] - 107s 502ms/step - loss: 0.0567 - accuracy: 0.9828 - val_loss: 2.2127 - val_accuracy: 0.6012
# Epoch 18/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9778Accuracy: 97.78%
# 214/214 [==============================] - 101s 471ms/step - loss: 0.0627 - accuracy: 0.9778 - val_loss: 2.5903 - val_accuracy: 0.5900
# Epoch 19/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9809Accuracy: 98.09%
# 214/214 [==============================] - 101s 474ms/step - loss: 0.0600 - accuracy: 0.9809 - val_loss: 2.4069 - val_accuracy: 0.6050
# Epoch 20/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9806Accuracy: 98.06%
# 214/214 [==============================] - 102s 479ms/step - loss: 0.0602 - accuracy: 0.9806 - val_loss: 2.7644 - val_accuracy: 0.5888
# Epoch 21/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9862Accuracy: 98.62%
# 214/214 [==============================] - 106s 493ms/step - loss: 0.0479 - accuracy: 0.9862 - val_loss: 2.7133 - val_accuracy: 0.5962
# Epoch 22/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9912Accuracy: 99.12%
# 214/214 [==============================] - 102s 477ms/step - loss: 0.0285 - accuracy: 0.9912 - val_loss: 3.0443 - val_accuracy: 0.5863
# Epoch 23/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9881Accuracy: 98.81%
# 214/214 [==============================] - 103s 482ms/step - loss: 0.0455 - accuracy: 0.9881 - val_loss: 3.5598 - val_accuracy: 0.5487
# Epoch 24/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9812Accuracy: 98.12%
# 214/214 [==============================] - 98s 460ms/step - loss: 0.0677 - accuracy: 0.9812 - val_loss: 3.1032 - val_accuracy: 0.5725
# Epoch 25/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9897Accuracy: 98.97%
# 214/214 [==============================] - 95s 445ms/step - loss: 0.0395 - accuracy: 0.9897 - val_loss: 2.9278 - val_accuracy: 0.5825
# Epoch 26/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9825Accuracy: 98.25%
# 214/214 [==============================] - 97s 455ms/step - loss: 0.0722 - accuracy: 0.9825 - val_loss: 2.9531 - val_accuracy: 0.5587
# Epoch 27/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9894Accuracy: 98.94%
# 214/214 [==============================] - 100s 465ms/step - loss: 0.0420 - accuracy: 0.9894 - val_loss: 3.6728 - val_accuracy: 0.5600
# Epoch 28/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9894Accuracy: 98.94%
# 214/214 [==============================] - 103s 483ms/step - loss: 0.0252 - accuracy: 0.9894 - val_loss: 3.5609 - val_accuracy: 0.5600
# Epoch 29/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9831Accuracy: 98.31%
# 214/214 [==============================] - 102s 478ms/step - loss: 0.0544 - accuracy: 0.9831 - val_loss: 3.2549 - val_accuracy: 0.5788
# Epoch 30/30
# 214/214 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9922Accuracy: 99.22%
# 214/214 [==============================] - 101s 471ms/step - loss: 0.0225 - accuracy: 0.9922 - val_loss: 3.2631 - val_accuracy: 0.5938

# %%
# training and validation loss
plt.plot(basic_cnn_hist6.history['loss'], label='Training Loss')
plt.plot(basic_cnn_hist6.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# training and validation accuracy
plt.plot(basic_cnn_hist6.history['accuracy'], label='Training Accuracy')
plt.plot(basic_cnn_hist6.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
preds = model.predict(test_images)
predicted_labels = np.argmax(preds, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

conf_mat6 = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat6, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 3s 118ms/step

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

class PrintAccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs.get('accuracy') * 100
        print(f'Accuracy: {accuracy:.2f}%')

def create_advanced_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def train_advanced_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size):
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

    learning_rate = 0.001
    optimizer = Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print_accuracy_callback = PrintAccuracyCallback()
    model.summary()
    advanced_cnn_hist = model.fit(train_images, train_labels, epochs=num_epochs, batch_size=batch_size,
                                  validation_data=(test_images, test_labels),
                                  callbacks=[early_stopping, reduce_lr, print_accuracy_callback])
    return advanced_cnn_hist

# constants
image_height = 224
image_width = 224
num_channels = 3
num_classes = 8
num_epochs = 100
batch_size = 15

model = create_advanced_cnn_model(input_shape=(image_height, image_width, num_channels), num_classes=num_classes)

advanced_cnn_hist = train_advanced_cnn_model(model, train_images, train_labels, test_images, test_labels, num_epochs, batch_size)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 222, 222, 32)      896
#
#  max_pooling2d_9 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  dropout_2 (Dropout)         (None, 111, 111, 32)      0
#
#  conv2d_12 (Conv2D)          (None, 109, 109, 64)      18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 54, 54, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 52, 52, 128)       73856
#
#  dropout_3 (Dropout)         (None, 52, 52, 128)       0
#
#  flatten_5 (Flatten)         (None, 346112)            0
#
#  dense_8 (Dense)             (None, 128)               44302464
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 44,396,744
# Trainable params: 44,396,744
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 214/214 [==============================] - ETA: 0s - loss: 1.9172 - accuracy: 0.2841Accuracy: 28.41%
# 214/214 [==============================] - 108s 500ms/step - loss: 1.9172 - accuracy: 0.2841 - val_loss: 1.5240 - val_accuracy: 0.4325 - lr: 0.0010
# Epoch 2/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2445 - accuracy: 0.5328Accuracy: 53.28%
# 214/214 [==============================] - 101s 471ms/step - loss: 1.2445 - accuracy: 0.5328 - val_loss: 0.9391 - val_accuracy: 0.6438 - lr: 0.0010
# Epoch 3/100
# 214/214 [==============================] - ETA: 0s - loss: 0.8550 - accuracy: 0.6859Accuracy: 68.59%
# 214/214 [==============================] - 99s 463ms/step - loss: 0.8550 - accuracy: 0.6859 - val_loss: 1.0857 - val_accuracy: 0.5975 - lr: 0.0010
# Epoch 4/100
# 214/214 [==============================] - ETA: 0s - loss: 0.6832 - accuracy: 0.7531Accuracy: 75.31%
# 214/214 [==============================] - 100s 468ms/step - loss: 0.6832 - accuracy: 0.7531 - val_loss: 0.7835 - val_accuracy: 0.7088 - lr: 0.0010
# Epoch 5/100
# 214/214 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.8072Accuracy: 80.72%
# 214/214 [==============================] - 99s 462ms/step - loss: 0.5456 - accuracy: 0.8072 - val_loss: 0.7743 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 6/100
# 214/214 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.8119Accuracy: 81.19%
# 214/214 [==============================] - 100s 468ms/step - loss: 0.5312 - accuracy: 0.8119 - val_loss: 0.6975 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 7/100
# 214/214 [==============================] - ETA: 0s - loss: 0.3906 - accuracy: 0.8650Accuracy: 86.50%
# 214/214 [==============================] - 101s 474ms/step - loss: 0.3906 - accuracy: 0.8650 - val_loss: 0.7999 - val_accuracy: 0.7275 - lr: 0.0010
# Epoch 8/100
# 214/214 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8834Accuracy: 88.34%
# 214/214 [==============================] - 97s 451ms/step - loss: 0.3364 - accuracy: 0.8834 - val_loss: 0.4289 - val_accuracy: 0.8512 - lr: 0.0010
# Epoch 9/100
# 214/214 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9022Accuracy: 90.22%
# 214/214 [==============================] - 95s 445ms/step - loss: 0.2852 - accuracy: 0.9022 - val_loss: 0.4310 - val_accuracy: 0.8687 - lr: 0.0010
# Epoch 10/100
# 214/214 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 0.9244Accuracy: 92.44%
# 214/214 [==============================] - 97s 451ms/step - loss: 0.2179 - accuracy: 0.9244 - val_loss: 0.5017 - val_accuracy: 0.8575 - lr: 0.0010
# Epoch 11/100
# 214/214 [==============================] - ETA: 0s - loss: 0.2491 - accuracy: 0.9125Accuracy: 91.25%
# 214/214 [==============================] - 96s 448ms/step - loss: 0.2491 - accuracy: 0.9125 - val_loss: 0.6352 - val_accuracy: 0.7925 - lr: 0.0010
# Epoch 12/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9541Accuracy: 95.41%
# 214/214 [==============================] - 97s 453ms/step - loss: 0.1456 - accuracy: 0.9541 - val_loss: 0.3681 - val_accuracy: 0.8925 - lr: 2.0000e-04
# Epoch 13/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9709Accuracy: 97.09%
# 214/214 [==============================] - 98s 460ms/step - loss: 0.0863 - accuracy: 0.9709 - val_loss: 0.3121 - val_accuracy: 0.9150 - lr: 2.0000e-04
# Epoch 14/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9762Accuracy: 97.62%
# 214/214 [==============================] - 99s 463ms/step - loss: 0.0631 - accuracy: 0.9762 - val_loss: 0.3369 - val_accuracy: 0.9137 - lr: 2.0000e-04
# Epoch 15/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9728Accuracy: 97.28%
# 214/214 [==============================] - 98s 456ms/step - loss: 0.0792 - accuracy: 0.9728 - val_loss: 0.3225 - val_accuracy: 0.9125 - lr: 2.0000e-04
# Epoch 16/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9825Accuracy: 98.25%
# 214/214 [==============================] - 97s 452ms/step - loss: 0.0528 - accuracy: 0.9825 - val_loss: 0.3373 - val_accuracy: 0.9187 - lr: 2.0000e-04
# Epoch 17/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9862Accuracy: 98.62%
# 214/214 [==============================] - 98s 460ms/step - loss: 0.0447 - accuracy: 0.9862 - val_loss: 0.3219 - val_accuracy: 0.9225 - lr: 4.0000e-05
# Epoch 18/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9837Accuracy: 98.37%
# 214/214 [==============================] - 102s 474ms/step - loss: 0.0471 - accuracy: 0.9837 - val_loss: 0.3193 - val_accuracy: 0.9287 - lr: 4.0000e-05

# %%
# training and validation loss
plt.plot(advanced_cnn_hist.history['loss'], label='Training Loss')
plt.plot(advanced_cnn_hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# training and validation accuracy
plt.plot(advanced_cnn_hist.history['accuracy'], label='Training Accuracy')
plt.plot(advanced_cnn_hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
preds = model.predict(test_images)
predicted_labels = np.argmax(preds, axis=1)

class_names = [
    "Anthracnose",
    "Bacterial Canker",
    "Cutting Weevil",
    "Die Back",
    "Gall Midge",
    "Healthy",
    "Powdery Mildew",
    "Sooty Mould"
]

conf_mat_adv = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat_adv, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 25/25 [==============================] - 3s 103ms/step
